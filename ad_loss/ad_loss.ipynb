# %% [markdown]
# # Анализ убыточности рекламы

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-предподоготовка-данных" data-toc-modified-id="Загрузка-и-предподоготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и предподоготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-файлов" data-toc-modified-id="Загрузка-файлов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка файлов</a></span></li><li><span><a href="#Изменение-названия-столбцов" data-toc-modified-id="Изменение-названия-столбцов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Изменение названия столбцов</a></span></li><li><span><a href="#Приведение-к-нижнему-регистру-данных-в-столбцах" data-toc-modified-id="Приведение-к-нижнему-регистру-данных-в-столбцах-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Приведение к нижнему регистру данных в столбцах</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Изменение типов данных</a></span></li></ul></li><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчёта и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-профилей-пользователей" data-toc-modified-id="Функция-для-создания-профилей-пользователей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания профилей пользователей</a></span></li><li><span><a href="#Функция-для-подсчёта-Retention-Rate" data-toc-modified-id="Функция-для-подсчёта-Retention-Rate-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для подсчёта Retention Rate</a></span></li><li><span><a href="#Функция-для-подсчёта-конверсии" data-toc-modified-id="Функция-для-подсчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для подсчёта конверсии</a></span></li><li><span><a href="#Функция-для-подсчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-подсчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для подсчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-данных-на-графиках" data-toc-modified-id="Функция-для-сглаживания-данных-на-графиках-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания данных на графиках</a></span></li><li><span><a href="#Функция-для-построения-графика-Retention-Rate" data-toc-modified-id="Функция-для-построения-графика-Retention-Rate-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для построения графика Retention Rate</a></span></li><li><span><a href="#Функция-для-построения-графика-конверсии" data-toc-modified-id="Функция-для-построения-графика-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для построения графика конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей.-Минимальная-и-максимальная-даты-привлечения-пользователей." data-toc-modified-id="Профили-пользователей.-Минимальная-и-максимальная-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей. Минимальная и максимальная даты привлечения пользователей.</a></span></li><li><span><a href="#Пользователи-по-странам" data-toc-modified-id="Пользователи-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Пользователи по странам</a></span></li><li><span><a href="#Пользователи-по-устройствам" data-toc-modified-id="Пользователи-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Пользователи по устройствам</a></span></li><li><span><a href="#Пользователи-по-рекламным-источникам" data-toc-modified-id="Пользователи-по-рекламным-источникам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Пользователи по рекламным источникам</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Распределение-трат-по-рекламным-источникам" data-toc-modified-id="Распределение-трат-по-рекламным-источникам-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Распределение трат по рекламным источникам</a></span></li><li><span><a href="#Динамика-изменения-расходов-по-неделям-и-по-месяцам" data-toc-modified-id="Динамика-изменения-расходов-по-неделям-и-по-месяцам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Динамика изменения расходов по неделям и по месяцам</a></span></li><li><span><a href="#Стоимость-привлечения-одного-пользователя" data-toc-modified-id="Стоимость-привлечения-одного-пользователя-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Стоимость привлечения одного пользователя</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-рекламы" data-toc-modified-id="Окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Окупаемость рекламы</a></span></li><li><span><a href="#Конверсия-и-удержание" data-toc-modified-id="Конверсия-и-удержание-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Конверсия и удержание</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-каналам" data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-каналам-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по каналам</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# **Цель проекта**
# Разобраться в причинах того, что компания Procrastinate Pro+ терпит убытки, несмотря на огромные вложения в рекламу, и помочь компании выйти в плюс.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# **План проекта:**
# 1. Загрузка и предподоготовка данных:
#     - загрузка файлов и изучение общей информации;
#     - предобработка данных на основе изучения общей информации.
# 2. Функции для расчёта и анализа LTV, ROI, удержания и конверсии.
# 3. Исследовательский анализ данных:
#     - Составить профили пользователей. Определить минимальную и максимальную даты привлечения пользователей.
#     - Выяснить, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.
#     - Определить, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
#     - Определить рекламные источники привлечения и каналы, из которых пришло больше всего платящих пользователей.
# 4. Маркетинг:
#     - Посчитать общую сумму расходов на маркетинг.
#     - Выяснить, как траты распределены по рекламным источникам.
#     - Построить график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику и по месяцам по каждому источнику.
#     - Определить, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.
# 5. Оценка окупаемости рекламы:
#     - Проанализировать окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.
#     - Проверить конверсию и удержание пользователей и динамику их изменения.
#     - Проанализировать окупаемость рекламы с разбивкой по устройствам, странам, рекламным каналам.

# %% [markdown]
# ## Загрузка и предподоготовка данных

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# ### Загрузка файлов

# %%
try:
    visits, orders, costs = (
        pd.read_csv('visits_info_short.csv'),
        pd.read_csv('orders_info_short.csv'),
        pd.read_csv('costs_info_short.csv')
    ) 
except:
    visits, orders, costs = (
        pd.read_csv('/datasets/visits_info_short.csv'),
        pd.read_csv('/datasets/orders_info_short.csv'),
        pd.read_csv('/datasets/costs_info_short.csv')
    )

# %%
visits.info(), orders.info(), costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %%
visits.head(5), orders.head(5), costs.head(5)
# Out:
# (        User Id         Region   Device  Channel        Session Start  \
#  0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
#  1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
#  2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
#  3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
#  4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#             Session End
#  0  2019-05-01 02:45:01
#  1  2019-05-01 04:47:35
#  2  2019-05-01 15:32:08
#  3  2019-05-01 00:54:25
#  4  2019-05-01 03:57:40  ,
#          User Id             Event Dt  Revenue
#  0  188246423999  2019-05-01 23:09:52     4.99
#  1  174361394180  2019-05-01 12:24:04     4.99
#  2  529610067795  2019-05-01 11:34:04     4.99
#  3  319939546352  2019-05-01 15:34:40     4.99
#  4  366000285810  2019-05-01 13:59:51     4.99,
#             dt   Channel  costs
#  0  2019-05-01  FaceBoom  113.3
#  1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# После изучения общей информации данные требуют следующей предобработки:
# - приведение к нижнему регистру название столбцов во всех трех датафреймах;
# - приведение к нижнему регистру данных в столбцах: `Channel`, `Region`, `Device`;
# - изменение типов данных для столбцов `dt`, `Event Dt`, `Session Start`, `Session End` к типу datetime;
# - проверка на явные и неявные дубликаты

# %% [markdown]
# ### Изменение названия столбцов

# %%
# воспользуемся функцией, чтобы привести к нижнему регистру все названия столбцов в датафрейме
# и между несколькими словами укажем символ нижнего подчеркивания
def columns_str(data):
    data.columns = data.columns.str.lower()
    data.columns = data.columns.str.replace(" ", "_")
    return data.columns
columns_str(visits), columns_str(orders), columns_str(costs)
# Out:
# (Index(['user_id', 'region', 'device', 'channel', 'session_start',
#         'session_end'],
#        dtype='object'),
#  Index(['user_id', 'event_dt', 'revenue'], dtype='object'),
#  Index(['dt', 'channel', 'costs'], dtype='object'))

# %% [markdown]
# ### Приведение к нижнему регистру данных в столбцах

# %%
# воспользуемся функцией str.lower()
costs['channel'] = costs['channel'].str.lower()
visits['region'] = visits['region'].str.lower()
visits['device'] = visits['device'].str.lower()
visits['channel'] = visits['channel'].str.lower()
visits.head(5), orders.head(5), costs.head(5)
# Out:
# (        user_id         region   device  channel        session_start  \
#  0  981449118918  united states   iphone  organic  2019-05-01 02:36:01
#  1  278965908054  united states   iphone  organic  2019-05-01 04:46:31
#  2  590706206550  united states      mac  organic  2019-05-01 14:09:25
#  3  326433527971  united states  android   tiptop  2019-05-01 00:29:59
#  4  349773784594  united states      mac  organic  2019-05-01 03:33:35
#
#             session_end
#  0  2019-05-01 02:45:01
#  1  2019-05-01 04:47:35
#  2  2019-05-01 15:32:08
#  3  2019-05-01 00:54:25
#  4  2019-05-01 03:57:40  ,
#          user_id             event_dt  revenue
#  0  188246423999  2019-05-01 23:09:52     4.99
#  1  174361394180  2019-05-01 12:24:04     4.99
#  2  529610067795  2019-05-01 11:34:04     4.99
#  3  319939546352  2019-05-01 15:34:40     4.99
#  4  366000285810  2019-05-01 13:59:51     4.99,
#             dt   channel  costs
#  0  2019-05-01  faceboom  113.3
#  1  2019-05-02  faceboom   78.1
# ...

# %% [markdown]
# ### Проверка на дубликаты

# %%
visits.duplicated().sum(), orders.duplicated().sum(), costs.duplicated().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# ### Изменение типов данных

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %% [markdown]
# **Вывод по итогам предобработки данных:**
# Данные предоставлены в трех датафреймах. Пропущенных данных и дубликатов не обнаружено. Были приведены названия столбцов и их содержимое к нижнему регистру, изменен тип данных для данных с датами и временем.

# %% [markdown]
# ## Функции для расчёта и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для создания профилей пользователей

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].values.astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для подсчёта Retention Rate

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для подсчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для подсчёта LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания данных на графиках

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для построения графика Retention Rate

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для построения графика конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей. Минимальная и максимальная даты привлечения пользователей.

# %%
# получим профили пользователей с помощью функции get_profiles()
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    faceboom     mac  united states
# 1   4919697 2019-07-09 12:46:07    faceboom  iphone  united states
# 2   6085896 2019-10-01 09:58:33     organic  iphone         france
# 3  22593348 2019-08-22 21:35:48  adnonsense      pc        germany
# 4  31989216 2019-10-02 00:07:44     yrabbit  iphone  united states
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# найдем минимальную и максимальную даты привлечения пользователей
min_date = profiles['first_ts'].min()
max_date = profiles['first_ts'].max()
min_date, max_date
# Out:
# (Timestamp('2019-05-01 00:00:41'), Timestamp('2019-10-27 23:59:04'))

# %% [markdown]
# Данные соответствуют теми данными, которые указаны в задании: "Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года".

# %%
days_num = (max_date - min_date).days
days_num
# Out:
# 179

# %% [markdown]
# **Исследуем данные пользователей, привлеченных за 179 дней с 1 мая 2019 года по 27 октября 2019 года.**

# %% [markdown]
# ### Пользователи по странам
#
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %% [markdown]
# Т.к. нам необходима разбивка пользователей не только по странам, но и по устройствам и источникам рекламы, напишем общую функцию для этой цели.

# %%
def users_by(index):
    data = (
        profiles # используем профили пользователй
        .groupby(index) # группировка
# считаем количество пользователей, количество плательщиков, долю плательщиков
        .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})    
    )
    # переименуем столбцы и сможем к ним обратиться
    data.columns = ['users_count', 'payers_count', 'payers_part']
    data = data.sort_values(by='payers_part', ascending=False) # сортировка 
    # выражаем долю платящих в процентах с округлением 
    data['payers_part'] = round(data['payers_part'] * 100, 1)
    return data

# %%
users_by('region')
# Out:
#                users_count  payers_count  payers_part
# region
# united states       100002          6902          6.9
# germany              14981           616          4.1
# uk                   17575           700          4.0
# france               17450           663          3.8

# %%
#Код ревьюера

countries = (profiles
             .groupby('region')
             .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
             .sort_values(by=('payer', 'sum'), ascending=False)
             .reset_index()
            )

countries.columns = ['Страна', 'Всего пользователей', 'Всего платящих', '% платящих']

countries.style.format({'% платящих': '{:.1%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_29d25_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Страна</th>        <th class="col_heading level0 col1" >Всего пользователей</th>        <th class="col_heading level0 col2" >Всего платящих</th>        <th class="col_heading level0 col3" >% платящих</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_29d25_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_29d25_row0_col0" class="data row0 col0" >united states</td>
#                         <td id="T_29d25_row0_col1" class="data row0 col1" >100002</td>
#                         <td id="T_29d25_row0_col2" class="data row0 col2" >6902</td>
#                         <td id="T_29d25_row0_col3" class="data row0 col3" >6.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_29d25_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# ###### **Приложение посещают пользователи из США, Германии, Великобритании, Франции. Причем наибольшее количество платящих пользователей из США (6,9%), а в остальных странах процент платящих пользователей примерно 4%.**

# %% [markdown]
# ### Пользователи по устройствам
#
# Определим, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
users_by('device')
# Out:
#          users_count  payers_count  payers_part
# device
# mac            30042          1912          6.4
# iphone         54479          3382          6.2
# android        35032          2050          5.9
# pc             30455          1537          5.0

# %% [markdown]
# **Для приложения пользователи используют следующие устройства: Mac, iPhone, Android, PC. При этом доля платящих пользователей на Mac и iPhone немного выше 6%, а на Android и PC 5,8% и 5% соответственно.**

# %% [markdown]
# ### Пользователи по рекламным источникам
#
# Определим рекламные источники привлечения и каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
users_by('channel')
# Out:
#                     users_count  payers_count  payers_part
# channel
# faceboom                  29144          3557         12.2
# adnonsense                 3880           440         11.3
# lambdamediaads             2149           225         10.5
# tiptop                    19561          1878          9.6
# rocketsuperads             4448           352          7.9
# wahoonetbanner             8553           453          5.3
# yrabbit                    4312           165          3.8
# mediatornado               4364           156          3.6
# leapbob                    8553           262          3.1
# opplecreativemedia         8605           233          2.7
# organic                   56439          1160          2.1

# %% [markdown]
# **Больше всего пользователей пришло из следующих источников: Organic, Faceboom, TipTop, но среди платящих пользователй лидируют: Faceboom, Adnonsens, Lambdamediaads**

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Распределение трат по рекламным источникам

# %% [markdown]
# Общая сумма расходов на маркетинг.

# %%
costs_sum = round(costs['costs'].sum(), 1)
print(f'Общая сумма расходов на маркетинг {costs_sum} у.е.')
# Out:
# Общая сумма расходов на маркетинг 105497.3 у.е.

# %% [markdown]
# Выясним, как траты распределены по рекламным источникам.

# %%
costs_grouped_channel = costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False)

costs_grouped_channel['costs_part'] = costs_grouped_channel['costs'] / costs_grouped_channel['costs'].sum()

costs_grouped_channel
# Out:
#                        costs  costs_part
# channel
# tiptop              54751.30    0.518983
# faceboom            32445.60    0.307549
# wahoonetbanner       5151.00    0.048826
# adnonsense           3911.25    0.037074
# opplecreativemedia   2151.25    0.020392
# rocketsuperads       1833.00    0.017375
# leapbob              1797.60    0.017039
# lambdamediaads       1557.60    0.014764
# mediatornado          954.48    0.009047
# yrabbit               944.22    0.008950

# %% [markdown]
# **Более 80% всех трат на рекламу приходится на Tiptop (52%) и Faceboom (31%), остальные 17% распределены между восьмью дополнительными источниками рекламы.**

# %% [markdown]
# ### Динамика изменения расходов по неделям и по месяцам

# %% [markdown]
# Построим график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику и по месяцам по каждому источнику.

# %%
costs['dt'] = pd.to_datetime(costs['dt'])
costs['week'] = costs['dt'].dt.isocalendar().week # добавим новый столбец с указанием номера недели в году
costs['month'] = costs['dt'].dt.month # добавим новый столбец с указанием номера месяца в году

# %%
plt.figure(figsize=(25, 15)) # задаём размер сетки для графиков

# расходы по неделям
costs_weekly = costs.pivot_table(index='channel', columns='week', values='costs', aggfunc='sum'
)
# расходы по месяцам
costs_monthly = costs.pivot_table(index='channel', columns='month', values='costs', aggfunc='sum'
)
# графици строим на одной сетке с помощью subplot()
# в первой строим изменение расходов по неделям
ax1 = plt.subplot(2, 2, 1)
costs_weekly.T.plot(
    grid=True, xticks=list(costs_weekly.columns.values), ax=ax1
)
plt.ylabel('Сумма расходов')
plt.title('Изменение расходов по неделям')
# во второй - изменение расходов по месяцам
ax2 = plt.subplot(2, 2, 2)
costs_monthly.T.plot(
    grid=True, xticks=list(costs_monthly.columns.values), ax=ax2
)
plt.ylabel('Сумма расходов')
plt.title('Изменение расходов по  месяцам')

plt.show()

# %% [markdown]
# **Вывод: основные траты приходятся на рекламу по двум источникам: Tiptop и Faceboom. Траты на все остальные источники рекламы распределены равномерно в течение всего периода, а на самые дорогие растут с увеличением периода, причем, если сравнить изменение расходов по неделям и по месяцам, то по неделям наблюдаются периодические снижения трат на рекламу, но засчет увеличения расходов уже со следующих недель, месячные траты в среднем не падают, а только растут. При этом расходы на Tiptop выделяются очень резким повышением в сентябре на 39 неделе. С 37 по 39 неделю расходы выросли на 1500 у.е. (условных единиц) и достигли максимального значения 4000 у.е., тогда как траты на большинство источников рекламы не превышает 250 у.е. в неделю.**

# %% [markdown]
# ### Стоимость привлечения одного пользователя

# %% [markdown]
# Определим, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
profiles.groupby('channel').agg({'acquisition_cost': 'mean'}).sort_values(by='acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# tiptop                      2.799003
# faceboom                    1.113286
# adnonsense                  1.008054
# lambdamediaads              0.724802
# wahoonetbanner              0.602245
# rocketsuperads              0.412095
# opplecreativemedia          0.250000
# yrabbit                     0.218975
# mediatornado                0.218717
# leapbob                     0.210172
# organic                     0.000000

# %% [markdown]
# Посмотрим, как изменялась цена

# %%
# строим график истории изменений CAC по каналам привлечения, используя профили пользователей
# исключаем из расчетов organic
profiles.query('channel != "organic"').pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC, у.е.')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# **Самая высокая средняя цена привлечения одного пользователя от TipTop, она в три раза превышает САС от  Adnonsens, Lambdamediaads, хотя они приносят больше платящих пользователей.**
# **При этом хочется также отметить и динамику стоимости привлечения одного пользователя у TipTop: начиная с 1 у.е. в мае эта стоимость растет каждый месяц на 0.5 у.е., при этом для остальных источников САС колеблется в районе первоначального значения в течение всего периода. Важно отметить и Faceboom, т.к. исходя из предыдущего исследования, траты на этот источник рекламы высокие и растут с каждой неделей, но при этом стоимость привлечение одного пользователя очень стабильна и составляет примерно 1.1 у.е. Также хочу отметить, что для Rocketsuperads за 3,5 месяца CAC уменьшилась вдвое.**

# %% [markdown]
# **Вывод по маркетингу:**
# **Всего за полгода на рекламу потрачено 105497.3 у.е., из них более половины ушло в Tiptop, причем с каждым месяцем сумма росла и также росла стоимость привлечения одного пользователя, при этом доля привлечения платящих пользователей от этого источника не в лидерах, ее обгоняют две комании, суммарная трата на рекламу которых составляет менее 5% (adnonsense - 3,7%, lambdamediaads - 1,5%), а также средняя цена привлечения одного пользователя в три раза меньше.**
# **Траты на рекламу на Faceboom составляют более 30%, эти траты также растут со временем, но достаточно умеренно, а также стоисмость привлечения одного пользователя очень стабильна и больше всего платящих пользователей именно от этого источника, поэтому подозреваю, что траты на рекламу на Faceboom оправданы, чего не могу сказать о Tiptop.**

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# ### Окупаемость рекламы

# %% [markdown]
# Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы. Будем считать, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.
#
# Установим момент и горизонт анализа данных.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# Перед исследованием окупаемости рекламы исключим из `profiles` данные с каналом `Organic`

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
# - Реклама не окупается. ROI в конце второй недели около 81%.
# - CAC в первый месяц стремительно растет, дальше с меньшей динамикой, но все равно повышается, после сентября был последний значительный рост и после этого слабо колеблется. Возможно, дело в увеличении рекламного бюджета.
# - LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
# - Динамика ROI показывает, что в мае окупаемость была, а в июне упала и уже не превышала расходы.

# %% [markdown]
# ### Конверсия и удержание
# Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучите графики конверсии и удержания.

# %%
# смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Судя по графикам пользователи конвертируются очень хорошо, проблем в этой части нет.**

# %%
# смотрим удержание

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Удержание платящих пользователей хорошее, а вот среди неплатящих пользователей практически нет таких, которые остаются с приложением до 14 дня.**

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам
# Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **У пользователей на PC самая низкая стоимость привлечения пользователей, при этом самая высокая окупаемость, рекламные инвестиции окупаются на 11-й день, а в динамике на 14-й день окупаются вплоть до августа.Пользователи на Mac и iPhone  обходятся компании дороже всего и при этом не окупаются.**

# %% [markdown]
# Проверим, есть ли разница между окупаемостью устройств отдельно в США и отдельно в Европе

# %%
profiles_usa = profiles.query('region == "united states"')
dimensions = ['device']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %%
profiles_europe = profiles.query('region != "united states"')
dimensions = ['device']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_europe, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **Графики показали, что реклама на всех устройствах в европейских странах окупается, причем стоимость привлечения одного пользователя с июня упала и остается стабильной до конца изучаемого периода. А в США расходы не окупаются ни на каком устройстве, а только растут расходы на рекламу.**

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам
# Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
 # смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **Для пользователей из США LTV очень хороший, но при этом и расход на рекламу сильно выше, чем в других странах, поэтому такая реклама не окупается. В других странах хоть и ниже LTV , но окупаемость очень хорошая при этом окупается в первую неделю.**

# %% [markdown]
# Посмотрим конверсию и удержание с разбивкой по каналам только для США

# %%
profiles_usa = profiles.query('region == "united states"')
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_usa, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **В США проблема с удержанием пользователей для FaceBoom. Следует обратить внимание, возможно, имеет место техническая ошибка.**

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам
# Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# смотрим окупаемость с разбивкой по рекламнным каналам

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **Самая дорогая реклама на Tiptop и Faceboom не окупается.**

# %% [markdown]
# Рассмотрим, какие рекламные источники окупаются в США и какие в европейских странах.

# %%
# США
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **В США окупаются следующие рекламные источники: YRabbit, MediaTornado, RocketSuperAds.**

# %%
# европейские страны
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_europe, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# **В европейских странах окупаются следующие рекламные источники: LambdaMediaAds, Leapbob, Opplecreativemedia, Wahoonetbanner.**

# %% [markdown]
# ### Конверсия и удержание с разбивкой по каналам

# %%
# смотрим конверсию с разбивкой по каналам
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание с разбивкой по каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Пользователи от рекламных источников FaceBoom и AdNonSense конвертируются лучше всех, но при этом у них очень плохое удержание. Скорее всего причина в технической ошибке.**

# %% [markdown]
# **Общий вывод по оценке окупаемости рекламы:**
# **Вцелом реклама не окупается, но это не общий случай, а в частности негативно на рекламу влияют следующие факторы:**
#
#     - Самая дорогая реклама на Tiptop и Faceboom не окупается.
#     - Проблема с удержанием пользователей от рекламных источников FaceBoom и AdNonSense.
#
# **Отделу маркетинга следует пересмотреть рекламную политику в отношении Tiptop, а также выявить техническую ошибку с удержанием пользователей от рекламных источников FaceBoom и AdNonSense**

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Целью проекта было - разобраться в причинах того, что компания Procrastinate Pro+ терпит убытки, несмотря на огромные вложения в рекламу, и помочь компании выйти в плюс.
#
# Данные предоставлены в трех датафреймах. Пропущенных данных и дубликатов не обнаружено. Были приведены названия столбцов и их содержимое к нижнему регистру, изменен тип данных для данных с датами и временем.
#
# Исследовались данные пользователей, привлеченных за 179 дней с 1 мая 2019 года по 27 октября 2019 года.
#
# Приложение посещают пользователи из США, Германии, Великобритании, Франции. Причем наибольшее количество платящих пользователей из США (7%), а в остальных странах процент платящих пользователей примерно 4%.
#
# Для приложения пользователи используют следующие устройства: Mac, iPhone, Android, PC. При этом доля платящих пользователей на Mac и iPhone немного выше 6%, а на Android и PC 5,8% и 5% соответственно.
#
# Больше всего пользователей пришло из следующих источников: Organic, Faceboom, TipTop, но среди платящих пользователй лидируют: Faceboom, Adnonsens, Lambdamediaads
#
# Всего за полгода на рекламу потрачено 105497.3 у.е., из них более половины ушло в Tiptop, причем с каждым месяцем сумма росла и также росла стоимость привлечения одного пользователя, при этом доля привлечения платящих пользователей от этого источника не в лидерах, ее обгоняют две комании, суммарная трата на рекламу которых составляет менее 5% (adnonsense - 3,7%, lambdamediaads - 1,5%), а также средняя цена привлечения одного пользователя в три раза меньше. Траты на рекламу на Faceboom составляют более 30%, эти траты также растут со временем, но достаточно умеренно, а также стоисмость привлечения одного пользователя очень стабильна и больше всего платящих пользователей именно от этого источника, поэтому подозреваю, что траты на рекламу на Faceboom оправданы, чего не могу сказать о Tiptop.
#
# Оценка окупаемости рекламы:
#
#     - Пользователи конвертируются очень хорошо, но удержание хорошее только для платящих пользователй, а вот среди неплатящих пользователей практически нет таких, которые остаются с приложением до 14 дня.
#     - Реклама на всех устройствах в европейских странах окупается, причем стоимость привлечения одного пользователя с июня упала и остается стабильной до конца изучаемого периода. А в США расходы не окупаются ни на каком устройстве, а только растут расходы на рекламу.
#     - Для пользователей из США LTV очень хороший, но при этом и расход на рекламу сильно выше, чем в других странах, поэтому такая реклама не окупается, но она не окупается только из-за одного источника FaceBoom, т.к. у FaceBoom проблема с удержанием пользователей. В других странах хоть и ниже LTV , но окупаемость очень хорошая при этом окупается в первую неделю.
#     - Самая дорогая реклама на Tiptop и Faceboom не окупается.
#     - Пользователи от рекламных источников FaceBoom и AdNonSense конвертируются лучше всех, но при этом у них очень плохое удержание.
#
# Общий вывод по оценке окупаемости рекламы: Вцелом реклама не окупается, но это не общий случай, а в частности негативно на рекламу влияют следующие факторы:
#
#     - Самая дорогая реклама на Tiptop и Faceboom не окупается.
#     - Проблема с удержанием пользователей от рекламных источников FaceBoom и AdNonSense.
#
# Отделу маркетинга следует:
#
#     - пересмотреть рекламную политику в отношении Tiptop;
#     - выявить техническую ошибку с удержанием пользователей от рекламных источников FaceBoom и AdNonSense;
#     - направить силы на привлечение пользователей, чтобы они переходили в статус "платящие";
#     - неэффективные каналы в США заменить на YRabbit, MediaTornado, RocketSuperAds;
#     - неэффективные каналы в европейских странах заменить на LambdaMediaAds, Leapbob, Opplecreativemedia, Wahoonetbanner.
